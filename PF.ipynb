# %% [markdown]
# # SAJID RAZAQ
# # BSAI-F24-049

# %%
import pandas as pd

# %%
import matplotlib as plt

# %%
df=pd.read_csv("country_wise_latest.csv",encoding= 'latin')
print(df)
# Out:
#          Country/Region  Confirmed  Deaths  Recovered  Active  New cases  \
# 0           Afghanistan      36263    1269      25198    9796        106
# 1               Albania       4880     144       2745    1991        117
# 2               Algeria      27973    1163      18837    7973        616
# 3               Andorra        907      52        803      52         10
# 4                Angola        950      41        242     667         18
# ..                  ...        ...     ...        ...     ...        ...
# 182  West Bank and Gaza      10621      78       3752    6791        152
# 183      Western Sahara         10       1          8       1          0
# 184               Yemen       1691     483        833     375         10
# 185              Zambia       4552     140       2815    1597         71
# 186            Zimbabwe       2704      36        542    2126        192
#
#      New deaths  New recovered  Deaths / 100 Cases  Recovered / 100 Cases  \
# ...

# %%
df=pd.read_csv("country_wise_latest.csv",encoding= 'latin')
print(df.to_string())
# Out:
#                        Country/Region  Confirmed  Deaths  Recovered   Active  New cases  New deaths  New recovered  Deaths / 100 Cases  Recovered / 100 Cases  Deaths / 100 Recovered  Confirmed last week  1 week change  1 week % increase             WHO Region
# 0                         Afghanistan      36263    1269      25198     9796        106          10             18                3.50                  69.49                    5.04                35526            737               2.07  Eastern Mediterranean
# 1                             Albania       4880     144       2745     1991        117           6             63                2.95                  56.25                    5.25                 4171            709              17.00                 Europe
# ...

# %%
df=pd.read_csv("country_wise_latest.csv",nrows=1)
print(df.to_string())
# Out:
#   Country/Region  Confirmed  Deaths  Recovered  Active  New cases  New deaths  New recovered  Deaths / 100 Cases  Recovered / 100 Cases  Deaths / 100 Recovered  Confirmed last week  1 week change  1 week % increase             WHO Region
# 0    Afghanistan      36263    1269      25198    9796        106          10             18                 3.5                  69.49                    5.04                35526            737               2.07  Eastern Mediterranean

# %%
df=pd.read_csv("country_wise_latest.csv",skiprows=1)
print(df.to_string())
# Out:
#                           Afghanistan    36263    1269    25198     9796    106    10     18    3.5   69.49     5.04    35526     737    2.07  Eastern Mediterranean
# 0                             Albania     4880     144     2745     1991    117     6     63   2.95   56.25     5.25     4171     709   17.00                 Europe
# 1                             Algeria    27973    1163    18837     7973    616     8    749   4.16   67.34     6.17    23691    4282   18.07                 Africa
# 2                             Andorra      907      52      803       52     10     0      0   5.73   88.53     6.48      884      23    2.60                 Europe
# 3                              Angola      950      41      242      667     18     1      0   4.32   25.47    16.94      749     201   26.84                 Africa
# ...

# %%
df=pd.read_csv("country_wise_latest.csv",index_col="Country/Region")
print(df.to_string())
# Out:
#                                   Confirmed  Deaths  Recovered   Active  New cases  New deaths  New recovered  Deaths / 100 Cases  Recovered / 100 Cases  Deaths / 100 Recovered  Confirmed last week  1 week change  1 week % increase             WHO Region
# Country/Region
# Afghanistan                           36263    1269      25198     9796        106          10             18                3.50                  69.49                    5.04                35526            737               2.07  Eastern Mediterranean
# Albania                                4880     144       2745     1991        117           6             63                2.95                  56.25                    5.25                 4171            709              17.00                 Europe
# ...

# %%
df=pd.read_csv("country_wise_latest.csv",header=6)
print(df.to_string())
# Out:
#                   Antigua and Barbuda       86       3       65       18      4     0      5   3.49   75.58     4.62       76      10   13.16               Americas
# 0                           Argentina   167416    3059    72575    91782   4890   120   2057   1.83   43.35     4.21   130774   36642   28.02               Americas
# 1                             Armenia    37390     711    26665    10014     73     6    187   1.90   71.32     2.67    34981    2409    6.89                 Europe
# 2                           Australia    15303     167     9311     5825    368     6    137   1.09   60.84     1.79    12428    2875   23.13        Western Pacific
# 3                             Austria    20558     713    18246     1599     86     1     37   3.47   88.75     3.91    19743     815    4.13                 Europe
# ...

# %%
df=pd.read_csv("country_wise_latest.csv",dtype={"Active":"float"})
print(df.to_string())
# Out:
#                        Country/Region  Confirmed  Deaths  Recovered     Active  New cases  New deaths  New recovered  Deaths / 100 Cases  Recovered / 100 Cases  Deaths / 100 Recovered  Confirmed last week  1 week change  1 week % increase             WHO Region
# 0                         Afghanistan      36263    1269      25198     9796.0        106          10             18                3.50                  69.49                    5.04                35526            737               2.07  Eastern Mediterranean
# 1                             Albania       4880     144       2745     1991.0        117           6             63                2.95                  56.25                    5.25                 4171            709              17.00                 Europe
# ...

# %%
df[100:111]
# Out:
#     Country/Region  Confirmed  Deaths  Recovered  Active  New cases  \
# 100  Liechtenstein         86       1         81     4.0          0
# 101      Lithuania       2019      80       1620   319.0         11
# 102     Luxembourg       6321     112       4825  1384.0         49
# 103     Madagascar       9690      91       6260  3339.0        395
# 104         Malawi       3664      99       1645  1920.0         24
# 105       Malaysia       8904     124       8601   179.0          7
# 106       Maldives       3369      15       2547   807.0         67
# 107           Mali       2513     124       1913   476.0          3
# 108          Malta        701       9        665    27.0          1
# 109     Mauritania       6208     156       4653  1399.0         37
# 110      Mauritius        344      10        332     2.0          0
#
#      New deaths  New recovered  Deaths / 100 Cases  Recovered / 100 Cases  \
# 100           0              0                1.16                  94.19
# ...

# %%
df.head()
# Out:
#   Country/Region  Confirmed  Deaths  Recovered  Active  New cases  New deaths  \
# 0    Afghanistan      36263    1269      25198    9796        106          10
# 1        Albania       4880     144       2745    1991        117           6
# 2        Algeria      27973    1163      18837    7973        616           8
# 3        Andorra        907      52        803      52         10           0
# 4         Angola        950      41        242     667         18           1
#
#    New recovered  Deaths / 100 Cases  Recovered / 100 Cases  \
# 0             18                3.50                  69.49
# 1             63                2.95                  56.25
# 2            749                4.16                  67.34
# 3              0                5.73                  88.53
# 4              0                4.32                  25.47
#
#    Deaths / 100 Recovered  Confirmed last week  1 week change  \
# 0                    5.04                35526            737
# ...

# %%
df.tail()
# Out:
#          Country/Region  Confirmed  Deaths  Recovered  Active  New cases  \
# 182  West Bank and Gaza      10621      78       3752    6791        152
# 183      Western Sahara         10       1          8       1          0
# 184               Yemen       1691     483        833     375         10
# 185              Zambia       4552     140       2815    1597         71
# 186            Zimbabwe       2704      36        542    2126        192
#
#      New deaths  New recovered  Deaths / 100 Cases  Recovered / 100 Cases  \
# 182           2              0                0.73                  35.33
# 183           0              0               10.00                  80.00
# 184           4             36               28.56                  49.26
# 185           1            465                3.08                  61.84
# 186           2             24                1.33                  20.04
#
#      Deaths / 100 Recovered  Confirmed last week  1 week change  \
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 187 entries, 0 to 186
# Data columns (total 15 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   Country/Region          187 non-null    object
#  1   Confirmed               187 non-null    int64
#  2   Deaths                  187 non-null    int64
#  3   Recovered               187 non-null    int64
#  4   Active                  187 non-null    int64
#  5   New cases               187 non-null    int64
#  6   New deaths              187 non-null    int64
#  7   New recovered           187 non-null    int64
#  8   Deaths / 100 Cases      187 non-null    float64
#  9   Recovered / 100 Cases   187 non-null    float64
#  10  Deaths / 100 Recovered  187 non-null    float64
#  11  Confirmed last week     187 non-null    int64
#  12  1 week change           187 non-null    int64
#  13  1 week % increase       187 non-null    float64
# ...

# %%
df.describe()
# Out:
#           Confirmed         Deaths     Recovered        Active     New cases  \
# count  1.870000e+02     187.000000  1.870000e+02  1.870000e+02    187.000000
# mean   8.813094e+04    3497.518717  5.063148e+04  3.400194e+04   1222.957219
# std    3.833187e+05   14100.002482  1.901882e+05  2.133262e+05   5710.374790
# min    1.000000e+01       0.000000  0.000000e+00  0.000000e+00      0.000000
# 25%    1.114000e+03      18.500000  6.265000e+02  1.415000e+02      4.000000
# 50%    5.059000e+03     108.000000  2.815000e+03  1.600000e+03     49.000000
# 75%    4.046050e+04     734.000000  2.260600e+04  9.149000e+03    419.500000
# max    4.290259e+06  148011.000000  1.846641e+06  2.816444e+06  56336.000000
#
#         New deaths  New recovered  Deaths / 100 Cases  Recovered / 100 Cases  \
# count   187.000000     187.000000          187.000000             187.000000
# mean     28.957219     933.812834            3.019519              64.820535
# ...

# %%
df.columns
# Out:
# Index(['Country/Region', 'Confirmed', 'Deaths', 'Recovered', 'Active',
#        'New cases', 'New deaths', 'New recovered', 'Deaths / 100 Cases',
#        'Recovered / 100 Cases', 'Deaths / 100 Recovered',
#        'Confirmed last week', '1 week change', '1 week % increase',
#        'WHO Region'],
#       dtype='object')

# %%
df["Country/Region"]
# Out:
# 0             Afghanistan
# 1                 Albania
# 2                 Algeria
# 3                 Andorra
# 4                  Angola
#               ...
# 182    West Bank and Gaza
# 183        Western Sahara
# 184                 Yemen
# 185                Zambia
# 186              Zimbabwe
# Name: Country/Region, Length: 187, dtype: object

# %%
df.shape
# Out:
# (187, 15)

# %%
df.rename(columns={"Country/Region":"COUNTRY"})
# Out:
#                 COUNTRY  Confirmed  Deaths  Recovered  Active  New cases  \
# 0           Afghanistan      36263    1269      25198    9796        106
# 1               Albania       4880     144       2745    1991        117
# 2               Algeria      27973    1163      18837    7973        616
# 3               Andorra        907      52        803      52         10
# 4                Angola        950      41        242     667         18
# ..                  ...        ...     ...        ...     ...        ...
# 182  West Bank and Gaza      10621      78       3752    6791        152
# 183      Western Sahara         10       1          8       1          0
# 184               Yemen       1691     483        833     375         10
# 185              Zambia       4552     140       2815    1597         71
# 186            Zimbabwe       2704      36        542    2126        192
#
#      New deaths  New recovered  Deaths / 100 Cases  Recovered / 100 Cases  \
# ...

# %%
df["Deaths"]>30
# Out:
# 0       True
# 1       True
# 2       True
# 3       True
# 4       True
#        ...
# 182     True
# 183    False
# 184     True
# 185     True
# 186     True
# Name: Deaths, Length: 187, dtype: bool

# %%
df[df["New recovered"]>1000]
# Out:
#          Country/Region  Confirmed  Deaths  Recovered   Active  New cases  \
# 6             Argentina     167416    3059      72575    91782       4890
# 13           Bangladesh     226225    2965     125683    97577       2772
# 23               Brazil    2442375   87618    1846641   508116      23284
# 35                Chile     347923    9187     319954    18782       2133
# 37             Colombia     257101    8777     131161   117163      16306
# 50   Dominican Republic      64156    1083      30204    32869       1248
# 52                Egypt      92482    4652      34838    52992        420
# 79                India    1480073   33408     951166   495499      44457
# 80            Indonesia     100303    4838      58173    37292       1525
# 81                 Iran     293606   15912     255144    22550       2434
# 82                 Iraq     112585    4458      77144    30983       2553
# 89           Kazakhstan      84648     585      54404    29659       1526
# ...

# %%
df[df["Active"]>15000]
# Out:
#          Country/Region  Confirmed  Deaths  Recovered   Active  New cases  \
# 6             Argentina     167416    3059      72575    91782       4890
# 13           Bangladesh     226225    2965     125683    97577       2772
# 16              Belgium      66428    9822      17452    39154        402
# 20              Bolivia      71181    2647      21478    47056       1752
# 23               Brazil    2442375   87618    1846641   508116      23284
# 32               Canada     116458    8944          0   107514        682
# 35                Chile     347923    9187     319954    18782       2133
# 37             Colombia     257101    8777     131161   117163      16306
# 50   Dominican Republic      64156    1083      30204    32869       1248
# 51              Ecuador      81161    5532      34896    40733        467
# 52                Egypt      92482    4652      34838    52992        420
# 61               France     220352   30212      81212   108928       2551
# ...

# %%
df[df["Country/Region"]=="Bangladesh"]
# Out:
#    Country/Region  Confirmed  Deaths  Recovered  Active  New cases  \
# 13     Bangladesh     226225    2965     125683   97577       2772
#
#     New deaths  New recovered  Deaths / 100 Cases  Recovered / 100 Cases  \
# 13          37           1801                1.31                  55.56
#
#     Deaths / 100 Recovered  Confirmed last week  1 week change  \
# 13                    2.36               207453          18772
#
#     1 week % increase       WHO Region
# 13               9.05  South-East Asia

# %%
df.sort_values(by="Deaths",ascending=True)
# Out:
#      Country/Region  Confirmed  Deaths  Recovered   Active  New cases  \
# 59             Fiji         27       0         18        9          0
# 75         Holy See         12       0         12        0          0
# 69          Grenada         23       0         23        0          0
# 94             Laos         20       0         19        1          0
# 68        Greenland         14       0         13        1          1
# ..              ...        ...     ...        ...      ...        ...
# 85            Italy     246286   35112     198593    12581        168
# 111          Mexico     395489   44022     303810    47657       4973
# 177  United Kingdom     301708   45844       1437   254427        688
# 23           Brazil    2442375   87618    1846641   508116      23284
# 173              US    4290259  148011    1325804  2816444      56336
#
#      New deaths  New recovered  Deaths / 100 Cases  Recovered / 100 Cases  \
# ...

# %%
df.sort_values(by="New cases",ascending=False)
# Out:
#         Country/Region  Confirmed  Deaths  Recovered   Active  New cases  \
# 173                 US    4290259  148011    1325804  2816444      56336
# 79               India    1480073   33408     951166   495499      44457
# 23              Brazil    2442375   87618    1846641   508116      23284
# 37            Colombia     257101    8777     131161   117163      16306
# 132               Peru     389717   18418     272547    98752      13756
# ..                 ...        ...     ...        ...      ...        ...
# 157              Spain     272421   28432     150376    93613          0
# 54   Equatorial Guinea       3071      51        842     2178          0
# 100      Liechtenstein         86       1         81        4          0
# 95              Latvia       1219      31       1045      143          0
# 56             Estonia       2034      69       1923       42          0
#
#      New deaths  New recovered  Deaths / 100 Cases  Recovered / 100 Cases  \
# ...

# %%
df.loc[9,"Deaths"]
# Out:
# 713

# %%
df.iloc[100]
# Out:
# Country/Region            Liechtenstein
# Confirmed                            86
# Deaths                                1
# Recovered                            81
# Active                                4
# New cases                             0
# New deaths                            0
# New recovered                         0
# Deaths / 100 Cases                 1.16
# Recovered / 100 Cases             94.19
# Deaths / 100 Recovered             1.23
# Confirmed last week                  86
# 1 week change                         0
# 1 week % increase                   0.0
# WHO Region                       Europe
# Name: 100, dtype: object

# %%
df.dtypes
# Out:
# Country/Region             object
# Confirmed                   int64
# Deaths                      int64
# Recovered                   int64
# Active                      int64
# New cases                   int64
# New deaths                  int64
# New recovered               int64
# Deaths / 100 Cases        float64
# Recovered / 100 Cases     float64
# Deaths / 100 Recovered    float64
# Confirmed last week         int64
# 1 week change               int64
# 1 week % increase         float64
# WHO Region                 object
# dtype: object

# %%
df["Confirmed"].mean()
# Out:
# 88130.935828877

# %%
df["Confirmed"].mode()
# Out:
# 0       24
# 1       86
# 2    10621
# Name: Confirmed, dtype: int64

# %%
df.isnull()
# Out:
#      Country/Region  Confirmed  Deaths  Recovered  Active  New cases  \
# 0             False      False   False      False   False      False
# 1             False      False   False      False   False      False
# 2             False      False   False      False   False      False
# 3             False      False   False      False   False      False
# 4             False      False   False      False   False      False
# ..              ...        ...     ...        ...     ...        ...
# 182           False      False   False      False   False      False
# 183           False      False   False      False   False      False
# 184           False      False   False      False   False      False
# 185           False      False   False      False   False      False
# 186           False      False   False      False   False      False
#
#      New deaths  New recovered  Deaths / 100 Cases  Recovered / 100 Cases  \
# ...

# %%
df.isnull().sum()
# Out:
# Country/Region            0
# Confirmed                 0
# Deaths                    0
# Recovered                 0
# Active                    0
# New cases                 0
# New deaths                0
# New recovered             0
# Deaths / 100 Cases        0
# Recovered / 100 Cases     0
# Deaths / 100 Recovered    0
# Confirmed last week       0
# 1 week change             0
# 1 week % increase         0
# WHO Region                0
# dtype: int64

# %%
df.dropna()
# Out:
#          Country/Region  Confirmed  Deaths  Recovered  Active  New cases  \
# 0           Afghanistan      36263    1269      25198    9796        106
# 1               Albania       4880     144       2745    1991        117
# 2               Algeria      27973    1163      18837    7973        616
# 3               Andorra        907      52        803      52         10
# 4                Angola        950      41        242     667         18
# ..                  ...        ...     ...        ...     ...        ...
# 182  West Bank and Gaza      10621      78       3752    6791        152
# 183      Western Sahara         10       1          8       1          0
# 184               Yemen       1691     483        833     375         10
# 185              Zambia       4552     140       2815    1597         71
# 186            Zimbabwe       2704      36        542    2126        192
#
#      New deaths  New recovered  Deaths / 100 Cases  Recovered / 100 Cases  \
# ...

# %%
df.dropna(how="any")
# Out:
#          Country/Region  Confirmed  Deaths  Recovered  Active  New cases  \
# 0           Afghanistan      36263    1269      25198  9796.0        106
# 1               Albania       4880     144       2745  1991.0        117
# 2               Algeria      27973    1163      18837  7973.0        616
# 3               Andorra        907      52        803    52.0         10
# 4                Angola        950      41        242   667.0         18
# ..                  ...        ...     ...        ...     ...        ...
# 182  West Bank and Gaza      10621      78       3752  6791.0        152
# 183      Western Sahara         10       1          8     1.0          0
# 184               Yemen       1691     483        833   375.0         10
# 185              Zambia       4552     140       2815  1597.0         71
# 186            Zimbabwe       2704      36        542  2126.0        192
#
#      New deaths  New recovered  Deaths / 100 Cases  Recovered / 100 Cases  \
# ...

# %%
df.dropna(how="all")
# Out:
#          Country/Region  Confirmed  Deaths  Recovered  Active  New cases  \
# 0           Afghanistan      36263    1269      25198  9796.0        106
# 1               Albania       4880     144       2745  1991.0        117
# 2               Algeria      27973    1163      18837  7973.0        616
# 3               Andorra        907      52        803    52.0         10
# 4                Angola        950      41        242   667.0         18
# ..                  ...        ...     ...        ...     ...        ...
# 182  West Bank and Gaza      10621      78       3752  6791.0        152
# 183      Western Sahara         10       1          8     1.0          0
# 184               Yemen       1691     483        833   375.0         10
# 185              Zambia       4552     140       2815  1597.0         71
# 186            Zimbabwe       2704      36        542  2126.0        192
#
#      New deaths  New recovered  Deaths / 100 Cases  Recovered / 100 Cases  \
# ...

# %%
df.dropna(inplace=True)
df
# Out:
#          Country/Region  Confirmed  Deaths  Recovered  Active  New cases  \
# 0           Afghanistan      36263    1269      25198  9796.0        106
# 1               Albania       4880     144       2745  1991.0        117
# 2               Algeria      27973    1163      18837  7973.0        616
# 3               Andorra        907      52        803    52.0         10
# 4                Angola        950      41        242   667.0         18
# ..                  ...        ...     ...        ...     ...        ...
# 182  West Bank and Gaza      10621      78       3752  6791.0        152
# 183      Western Sahara         10       1          8     1.0          0
# 184               Yemen       1691     483        833   375.0         10
# 185              Zambia       4552     140       2815  1597.0         71
# 186            Zimbabwe       2704      36        542  2126.0        192
#
#      New deaths  New recovered  Deaths / 100 Cases  Recovered / 100 Cases  \
# ...

# %%
df.fillna(4)
# Out:
#          Country/Region  Confirmed  Deaths  Recovered  Active  New cases  \
# 0           Afghanistan      36263    1269      25198    9796        106
# 1               Albania       4880     144       2745    1991        117
# 2               Algeria      27973    1163      18837    7973        616
# 3               Andorra        907      52        803      52         10
# 4                Angola        950      41        242     667         18
# ..                  ...        ...     ...        ...     ...        ...
# 182  West Bank and Gaza      10621      78       3752    6791        152
# 183      Western Sahara         10       1          8       1          0
# 184               Yemen       1691     483        833     375         10
# 185              Zambia       4552     140       2815    1597         71
# 186            Zimbabwe       2704      36        542    2126        192
#
#      New deaths  New recovered  Deaths / 100 Cases  Recovered / 100 Cases  \
# ...

# %%
df["Deaths"].fillna(100,inplace=True)
print(df)
# Out:
#          Country/Region  Confirmed  Deaths  Recovered  Active  New cases  \
# 0           Afghanistan      36263    1269      25198    9796        106
# 1               Albania       4880     144       2745    1991        117
# 2               Algeria      27973    1163      18837    7973        616
# 3               Andorra        907      52        803      52         10
# 4                Angola        950      41        242     667         18
# ..                  ...        ...     ...        ...     ...        ...
# 182  West Bank and Gaza      10621      78       3752    6791        152
# 183      Western Sahara         10       1          8       1          0
# 184               Yemen       1691     483        833     375         10
# 185              Zambia       4552     140       2815    1597         71
# 186            Zimbabwe       2704      36        542    2126        192
#
#      New deaths  New recovered  Deaths / 100 Cases  Recovered / 100 Cases  \
# ...

# %%
df['Deaths'].fillna(1000)
# Out:
# 0      1269
# 1       144
# 2      1163
# 3        52
# 4        41
#        ...
# 182      78
# 183       1
# 184     483
# 185     140
# 186      36
# Name: Deaths, Length: 187, dtype: int64

# %%
print(df.duplicated())
# Out:
# 0      False
# 1      False
# 2      False
# 3      False
# 4      False
#        ...
# 182    False
# 183    False
# 184    False
# 185    False
# 186    False
# Length: 187, dtype: bool

# %%
df['col']=188
df
# Out:
#          Country/Region  Confirmed  Deaths  Recovered  Active  New cases  \
# 0           Afghanistan      36263    1269      25198    9796        106
# 1               Albania       4880     144       2745    1991        117
# 2               Algeria      27973    1163      18837    7973        616
# 3               Andorra        907      52        803      52         10
# 4                Angola        950      41        242     667         18
# ..                  ...        ...     ...        ...     ...        ...
# 182  West Bank and Gaza      10621      78       3752    6791        152
# 183      Western Sahara         10       1          8       1          0
# 184               Yemen       1691     483        833     375         10
# 185              Zambia       4552     140       2815    1597         71
# 186            Zimbabwe       2704      36        542    2126        192
#
#      New deaths  New recovered  Deaths / 100 Cases  Recovered / 100 Cases  \
# ...

# %%
df["Deaths"].plot(kind="bar")
# Out:
# <Axes: >

# %%
df["New cases"].plot(kind="pie")
# Out:
# <Axes: ylabel='New cases'>

# %%
df["Deaths"].plot(kind='area')
# Out:
# <Axes: >

# %%
df["Deaths"].plot(kind="barh")
# Out:
# <Axes: >

# %%
df["Deaths / 100 Cases"].plot(kind="kde")
# Out:
# <Axes: ylabel='Density'>

# %%
df["Deaths"].plot(kind="hist")
# Out:
# <Axes: ylabel='Frequency'>

# %%
df["New deaths"].plot(kind="density")
# Out:
# <Axes: ylabel='Density'>

# %%
df["Deaths"].plot(kind="line")
# Out:
# <Axes: >

# %%
df["Confirmed last week"].plot(kind="box")
# Out:
# <Axes: >
